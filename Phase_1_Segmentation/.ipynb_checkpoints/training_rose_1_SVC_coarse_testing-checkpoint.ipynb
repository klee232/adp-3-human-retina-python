# %% [markdown]
# # training function (ROSE-1 SVC coarse) testing notebook:

# %% [markdown]
# This notebook is created for the intension of testing the training function for ROSE-1 SVC coarse model.

# %%
# add directory
import sys
sys.path.append(r"C:\Users\klee232\Desktop\Thesis\personal-GitHub\adp-3-human-retina-python\Phase_1_Segmentation")

# %%
# import all functions needed tested
# passed: successfully load all functions
from data_function_2D import * 
from models_2D import *

# %% [markdown]
# ## Load dataset:

# %% [markdown]
# ### Loading:

# %%
# run load_rose_1_dataset() function first 
output = load_rose_1_dataset()
# SVC
train_ROSE_SVC_org = output["train_ROSE_SVC_org"]
train_ROSE_SVC_orgGt = output["train_ROSE_SVC_orgGt"]
train_ROSE_SVC_thickGt = output["train_ROSE_SVC_thickGt"]
train_ROSE_SVC_thinGt = output["train_ROSE_SVC_thinGt"]
test_ROSE_SVC_org = output["test_ROSE_SVC_org"]
test_ROSE_SVC_orgGt = output["test_ROSE_SVC_orgGt"]
test_ROSE_SVC_thickGt = output["test_ROSE_SVC_thickGt"]
test_ROSE_SVC_thinGt = output["test_ROSE_SVC_thinGt"]

# %% [markdown]
# ## Launch training function:

# %%
trained_net = train_rose_1_SVC_coarse(output, num_epoch=200, learning_rate=3e-4, use_aug=True, early_break_counter=40)
# Out:
# C:\Users\klee232\Desktop\Thesis\personal-GitHub\adp-3-human-retina-python\Phase_1_Segmentation\models_2D\resume_checking.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(model_p, map_location=map_loc)
# C:\Users\klee232\Desktop\Thesis\personal-GitHub\adp-3-human-retina-python\Phase_1_Segmentation\models_2D\resume_checking.py:113: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt_param = torch.load(param_p, map_location=map_loc)
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 trained_net = train_rose_1_SVC_coarse(output, num_epoch=200, learning_rate=3e-4, use_aug=True, early_break_counter=40)
#
# File ~\Desktop\Thesis\personal-GitHub\adp-3-human-retina-python\Phase_1_Segmentation\models_2D\training_rose_1_SVC_coarse.py:390, in train_rose_1_SVC_coarse(overall_data, num_epoch, learning_rate, checkpoint_dir, prefix, use_amp, use_aug, early_break_counter)
#     387 plt.show()
#     389 # save final outcome
# --> 390 net_name = best_model.__class__.__name__
#     391 torch.save(best_model.state_dict(), f"trained_{net_name}.pth")
#     393 return best_model
#
# UnboundLocalError: cannot access local variable 'best_model' where it is not associated with a value

# %%
# ideal early_break_counter = 40
trained_net = train_rose_1_SVC_coarse(output, num_epoch=200, learning_rate=3e-4, use_aug=True, early_break_counter=80)
# Out:
# Current Epoch: 10 | Loss value 0.7538085082202282
# Current Epoch: 10 | Validation Loss value 0.6770271573747907
# Epoch [10/200] finished in 407.84 seconds (6.80 minutes)
# Fold [1/4.0] | Epoch [10/200] | Train Loss: 0.7538 | Val Loss: 0.6770
# Current Epoch: 20 | Loss value 0.7203575042844976
# Current Epoch: 20 | Validation Loss value 0.6651632956096104
# Epoch [20/200] finished in 383.20 seconds (6.39 minutes)
# Fold [1/4.0] | Epoch [20/200] | Train Loss: 0.7204 | Val Loss: 0.6652
# Current Epoch: 30 | Loss value 0.7066005121157007
# Current Epoch: 30 | Validation Loss value 0.66006452696664
# Epoch [30/200] finished in 381.02 seconds (6.35 minutes)
# Fold [1/4.0] | Epoch [30/200] | Train Loss: 0.7066 | Val Loss: 0.6601
# Current Epoch: 40 | Loss value 0.6835166655697869
# Current Epoch: 40 | Validation Loss value 0.6619179759706769
# Epoch [40/200] finished in 383.34 seconds (6.39 minutes)
# Fold [1/4.0] | Epoch [40/200] | Train Loss: 0.6835 | Val Loss: 0.6619
# Current Epoch: 50 | Loss value 0.6713383463979925
# Current Epoch: 50 | Validation Loss value 0.661919116973877
# Epoch [50/200] finished in 382.64 seconds (6.38 minutes)
# Fold [1/4.0] | Epoch [50/200] | Train Loss: 0.6713 | Val Loss: 0.6619
# Current Epoch: 60 | Loss value 0.6543326557261272
# Current Epoch: 60 | Validation Loss value 0.6437074797494071
# Epoch [60/200] finished in 382.70 seconds (6.38 minutes)
# Fold [1/4.0] | Epoch [60/200] | Train Loss: 0.6543 | Val Loss: 0.6437
# Current Epoch: 70 | Loss value 0.6437490935464507
# Current Epoch: 70 | Validation Loss value 0.6431052003587995
# Epoch [70/200] finished in 380.59 seconds (6.34 minutes)
# Fold [1/4.0] | Epoch [70/200] | Train Loss: 0.6437 | Val Loss: 0.6431
# Current Epoch: 80 | Loss value 0.6229649782180786
# Current Epoch: 80 | Validation Loss value 0.6482366493770054
# Epoch [80/200] finished in 380.38 seconds (6.34 minutes)
# Fold [1/4.0] | Epoch [80/200] | Train Loss: 0.6230 | Val Loss: 0.6482
# Current Epoch: 90 | Loss value 0.6118524878927805
# Current Epoch: 90 | Validation Loss value 0.632427453994751
# Epoch [90/200] finished in 382.05 seconds (6.37 minutes)
# Fold [1/4.0] | Epoch [90/200] | Train Loss: 0.6119 | Val Loss: 0.6324
# Current Epoch: 100 | Loss value 0.5837558261977817
# Current Epoch: 100 | Validation Loss value 0.6556817463466099
# Epoch [100/200] finished in 380.64 seconds (6.34 minutes)
# Fold [1/4.0] | Epoch [100/200] | Train Loss: 0.5838 | Val Loss: 0.6557
# Current Epoch: 110 | Loss value 0.5545289826045916
# Current Epoch: 110 | Validation Loss value 0.6516616003853934
# Epoch [110/200] finished in 380.52 seconds (6.34 minutes)
# Fold [1/4.0] | Epoch [110/200] | Train Loss: 0.5545 | Val Loss: 0.6517
# Current Epoch: 120 | Loss value 0.5285464681467964
# Current Epoch: 120 | Validation Loss value 0.6593128613063267
# Epoch [120/200] finished in 380.50 seconds (6.34 minutes)
# Fold [1/4.0] | Epoch [120/200] | Train Loss: 0.5285 | Val Loss: 0.6593
# Current Epoch: 130 | Loss value 0.5073084834131222
# Current Epoch: 130 | Validation Loss value 0.6737813779285976
# Epoch [130/200] finished in 377.93 seconds (6.30 minutes)
# Fold [1/4.0] | Epoch [130/200] | Train Loss: 0.5073 | Val Loss: 0.6738
# Early Break Activated
# Fold [1/4.0] | Epoch [136/200] | Train Loss: 0.4921 | Val Loss: 0.6923
# Current Epoch: 10 | Loss value 0.767755249750267
# Current Epoch: 10 | Validation Loss value 0.6697835922241211
# Epoch [10/200] finished in 375.49 seconds (6.26 minutes)
# Fold [2/4.0] | Epoch [10/200] | Train Loss: 0.7678 | Val Loss: 0.6698
# Current Epoch: 20 | Loss value 0.7210850501523435
# Current Epoch: 20 | Validation Loss value 0.645221369607108
# Epoch [20/200] finished in 375.77 seconds (6.26 minutes)
# Fold [2/4.0] | Epoch [20/200] | Train Loss: 0.7211 | Val Loss: 0.6452
# Current Epoch: 30 | Loss value 0.6929669212369085
# Current Epoch: 30 | Validation Loss value 0.6414695126669747
# Epoch [30/200] finished in 371.96 seconds (6.20 minutes)
# Fold [2/4.0] | Epoch [30/200] | Train Loss: 0.6930 | Val Loss: 0.6415
# Current Epoch: 40 | Loss value 0.6842595454558585
# Current Epoch: 40 | Validation Loss value 0.6324023178645543
# Epoch [40/200] finished in 371.19 seconds (6.19 minutes)
# Fold [2/4.0] | Epoch [40/200] | Train Loss: 0.6843 | Val Loss: 0.6324
# Current Epoch: 50 | Loss value 0.6656386082612195
# Current Epoch: 50 | Validation Loss value 0.6475518090384347
# Epoch [50/200] finished in 368.74 seconds (6.15 minutes)
# Fold [2/4.0] | Epoch [50/200] | Train Loss: 0.6656 | Val Loss: 0.6476
# Current Epoch: 60 | Loss value 0.6442180165966738
# Current Epoch: 60 | Validation Loss value 0.6676910264151437
# Epoch [60/200] finished in 369.56 seconds (6.16 minutes)
# Fold [2/4.0] | Epoch [60/200] | Train Loss: 0.6442 | Val Loss: 0.6677
# Current Epoch: 70 | Loss value 0.6320647637820939
# Current Epoch: 70 | Validation Loss value 0.6666370119367327
# Epoch [70/200] finished in 368.28 seconds (6.14 minutes)
# Fold [2/4.0] | Epoch [70/200] | Train Loss: 0.6321 | Val Loss: 0.6666
# Current Epoch: 80 | Loss value 0.6100832067647026
# Current Epoch: 80 | Validation Loss value 0.6658848694392613
# Epoch [80/200] finished in 368.47 seconds (6.14 minutes)
# Fold [2/4.0] | Epoch [80/200] | Train Loss: 0.6101 | Val Loss: 0.6659
# Current Epoch: 90 | Loss value 0.5713463862544125
# Current Epoch: 90 | Validation Loss value 0.634580271584647
# Epoch [90/200] finished in 369.42 seconds (6.16 minutes)
# Fold [2/4.0] | Epoch [90/200] | Train Loss: 0.5713 | Val Loss: 0.6346
# Current Epoch: 100 | Loss value 0.5513904424546991
# Current Epoch: 100 | Validation Loss value 0.639451435634068
# Epoch [100/200] finished in 368.04 seconds (6.13 minutes)
# Fold [2/4.0] | Epoch [100/200] | Train Loss: 0.5514 | Val Loss: 0.6395
# Current Epoch: 110 | Loss value 0.5216113467818325
# Current Epoch: 110 | Validation Loss value 0.6511616025652204
# Epoch [110/200] finished in 367.98 seconds (6.13 minutes)
# Fold [2/4.0] | Epoch [110/200] | Train Loss: 0.5216 | Val Loss: 0.6512
# Current Epoch: 120 | Loss value 0.5029224177587379
# Current Epoch: 120 | Validation Loss value 0.6427374567304339
# Epoch [120/200] finished in 368.91 seconds (6.15 minutes)
# Fold [2/4.0] | Epoch [120/200] | Train Loss: 0.5029 | Val Loss: 0.6427
# Current Epoch: 130 | Loss value 0.4832944600906187
# Current Epoch: 130 | Validation Loss value 0.6768334593091693
# Epoch [130/200] finished in 369.66 seconds (6.16 minutes)
# Fold [2/4.0] | Epoch [130/200] | Train Loss: 0.4833 | Val Loss: 0.6768
# Early Break Activated
# Fold [2/4.0] | Epoch [137/200] | Train Loss: 0.4794 | Val Loss: 0.6484
# Current Epoch: 10 | Loss value 0.78152258014216
# Current Epoch: 10 | Validation Loss value 0.6675345557076591
# Epoch [10/200] finished in 380.01 seconds (6.33 minutes)
# Fold [3/4.0] | Epoch [10/200] | Train Loss: 0.7815 | Val Loss: 0.6675
# Current Epoch: 20 | Loss value 0.7500882200824405
# Current Epoch: 20 | Validation Loss value 0.6421189648764474
# Epoch [20/200] finished in 492.85 seconds (8.21 minutes)
# Fold [3/4.0] | Epoch [20/200] | Train Loss: 0.7501 | Val Loss: 0.6421
# Current Epoch: 30 | Loss value 0.7278980028282092
# Current Epoch: 30 | Validation Loss value 0.6236330270767212
# Epoch [30/200] finished in 426.22 seconds (7.10 minutes)
# Fold [3/4.0] | Epoch [30/200] | Train Loss: 0.7279 | Val Loss: 0.6236
# Current Epoch: 40 | Loss value 0.7125530347083379
# Current Epoch: 40 | Validation Loss value 0.6153951031821114
# Epoch [40/200] finished in 427.07 seconds (7.12 minutes)
# Fold [3/4.0] | Epoch [40/200] | Train Loss: 0.7126 | Val Loss: 0.6154
# Current Epoch: 50 | Loss value 0.6960587171674932
# Current Epoch: 50 | Validation Loss value 0.5935532706124442
# Epoch [50/200] finished in 431.48 seconds (7.19 minutes)
# Fold [3/4.0] | Epoch [50/200] | Train Loss: 0.6961 | Val Loss: 0.5936
# Current Epoch: 60 | Loss value 0.6874250433977368
# Current Epoch: 60 | Validation Loss value 0.5944316727774483
# Epoch [60/200] finished in 423.36 seconds (7.06 minutes)
# Fold [3/4.0] | Epoch [60/200] | Train Loss: 0.6874 | Val Loss: 0.5944
# Current Epoch: 70 | Loss value 0.6652697110639035
# Current Epoch: 70 | Validation Loss value 0.579242501940046
# Epoch [70/200] finished in 423.80 seconds (7.06 minutes)
# Fold [3/4.0] | Epoch [70/200] | Train Loss: 0.6653 | Val Loss: 0.5792
# Current Epoch: 80 | Loss value 0.6418387374831634
# Current Epoch: 80 | Validation Loss value 0.6124258552278791
# Epoch [80/200] finished in 425.32 seconds (7.09 minutes)
# Fold [3/4.0] | Epoch [80/200] | Train Loss: 0.6418 | Val Loss: 0.6124
# Current Epoch: 90 | Loss value 0.6248973179789423
# Current Epoch: 90 | Validation Loss value 0.636211463383266
# Epoch [90/200] finished in 424.11 seconds (7.07 minutes)
# Fold [3/4.0] | Epoch [90/200] | Train Loss: 0.6249 | Val Loss: 0.6362
# Current Epoch: 100 | Loss value 0.5860371282957133
# Current Epoch: 100 | Validation Loss value 0.6084907054901123
# Epoch [100/200] finished in 423.79 seconds (7.06 minutes)
# Fold [3/4.0] | Epoch [100/200] | Train Loss: 0.5860 | Val Loss: 0.6085
# Current Epoch: 110 | Loss value 0.5531637295357232
# Current Epoch: 110 | Validation Loss value 0.6283221585409982
# Epoch [110/200] finished in 423.44 seconds (7.06 minutes)
# Fold [3/4.0] | Epoch [110/200] | Train Loss: 0.5532 | Val Loss: 0.6283
# Current Epoch: 120 | Loss value 0.5259529355081539
# Current Epoch: 120 | Validation Loss value 0.6406562668936593
# Epoch [120/200] finished in 423.34 seconds (7.06 minutes)
# Fold [3/4.0] | Epoch [120/200] | Train Loss: 0.5260 | Val Loss: 0.6407
# Current Epoch: 130 | Loss value 0.5120053421525121
# Current Epoch: 130 | Validation Loss value 0.6458298478807721
# Epoch [130/200] finished in 423.21 seconds (7.05 minutes)
# Fold [3/4.0] | Epoch [130/200] | Train Loss: 0.5120 | Val Loss: 0.6458
# Current Epoch: 140 | Loss value 0.4894270951886779
# Current Epoch: 140 | Validation Loss value 0.6468235424586705
# Epoch [140/200] finished in 423.01 seconds (7.05 minutes)
# Fold [3/4.0] | Epoch [140/200] | Train Loss: 0.4894 | Val Loss: 0.6468
# Current Epoch: 150 | Loss value 0.468484612923224
# Current Epoch: 150 | Validation Loss value 0.6242319175175258
# Epoch [150/200] finished in 437.81 seconds (7.30 minutes)
# Fold [3/4.0] | Epoch [150/200] | Train Loss: 0.4685 | Val Loss: 0.6242
# Current Epoch: 160 | Loss value 0.4584595925599626
# Current Epoch: 160 | Validation Loss value 0.6360628264290946
# Epoch [160/200] finished in 763.70 seconds (12.73 minutes)
# Fold [3/4.0] | Epoch [160/200] | Train Loss: 0.4585 | Val Loss: 0.6361
# Current Epoch: 170 | Loss value 0.44162574960190115
# Current Epoch: 170 | Validation Loss value 0.6489993844713483
# Epoch [170/200] finished in 1409.65 seconds (23.49 minutes)
# Early Break Activated
# Fold [3/4.0] | Epoch [170/200] | Train Loss: 0.4416 | Val Loss: 0.6490
# Current Epoch: 10 | Loss value 0.7851925000403691
# Current Epoch: 10 | Validation Loss value 0.695080178124564
# Epoch [10/200] finished in 1419.93 seconds (23.67 minutes)
# Fold [4/4.0] | Epoch [10/200] | Train Loss: 0.7852 | Val Loss: 0.6951
# Current Epoch: 20 | Loss value 0.7363693326422311
# Current Epoch: 20 | Validation Loss value 0.6800458090645927
# Epoch [20/200] finished in 1165.26 seconds (19.42 minutes)
# Fold [4/4.0] | Epoch [20/200] | Train Loss: 0.7364 | Val Loss: 0.6800
# Current Epoch: 30 | Loss value 0.7071845595119068
# Current Epoch: 30 | Validation Loss value 0.6788449968610492
# Epoch [30/200] finished in 481.38 seconds (8.02 minutes)
# Fold [4/4.0] | Epoch [30/200] | Train Loss: 0.7072 | Val Loss: 0.6788
# Current Epoch: 40 | Loss value 0.6978408266039728
# Current Epoch: 40 | Validation Loss value 0.6421645879745483
# Epoch [40/200] finished in 473.17 seconds (7.89 minutes)
# Fold [4/4.0] | Epoch [40/200] | Train Loss: 0.6978 | Val Loss: 0.6422
# Current Epoch: 50 | Loss value 0.6818770887782273
# Current Epoch: 50 | Validation Loss value 0.6550536155700684
# Epoch [50/200] finished in 472.10 seconds (7.87 minutes)
# Fold [4/4.0] | Epoch [50/200] | Train Loss: 0.6819 | Val Loss: 0.6551
# Current Epoch: 60 | Loss value 0.6682024019435772
# Current Epoch: 60 | Validation Loss value 0.6449567590441022
# Epoch [60/200] finished in 475.44 seconds (7.92 minutes)
# Fold [4/4.0] | Epoch [60/200] | Train Loss: 0.6682 | Val Loss: 0.6450
# Current Epoch: 70 | Loss value 0.6508503284269166
# Current Epoch: 70 | Validation Loss value 0.6458085605076381
# Epoch [70/200] finished in 472.87 seconds (7.88 minutes)
# Fold [4/4.0] | Epoch [70/200] | Train Loss: 0.6509 | Val Loss: 0.6458
# Current Epoch: 80 | Loss value 0.6209033733432733
# Current Epoch: 80 | Validation Loss value 0.6599853379385812
# Epoch [80/200] finished in 471.53 seconds (7.86 minutes)
# Fold [4/4.0] | Epoch [80/200] | Train Loss: 0.6209 | Val Loss: 0.6600
# Current Epoch: 90 | Loss value 0.6028157229562408
# Current Epoch: 90 | Validation Loss value 0.648827314376831
# Epoch [90/200] finished in 470.78 seconds (7.85 minutes)
# Fold [4/4.0] | Epoch [90/200] | Train Loss: 0.6028 | Val Loss: 0.6488
# Current Epoch: 100 | Loss value 0.5712283545906104
# Current Epoch: 100 | Validation Loss value 0.6596031188964844
# Epoch [100/200] finished in 470.43 seconds (7.84 minutes)
# Fold [4/4.0] | Epoch [100/200] | Train Loss: 0.5712 | Val Loss: 0.6596
# Current Epoch: 110 | Loss value 0.5483496411911493
# Current Epoch: 110 | Validation Loss value 0.6723801067897252
# Epoch [110/200] finished in 469.87 seconds (7.83 minutes)
# Fold [4/4.0] | Epoch [110/200] | Train Loss: 0.5483 | Val Loss: 0.6724
# Current Epoch: 120 | Loss value 0.5204122870871164
# Current Epoch: 120 | Validation Loss value 0.6880761555262974
# Epoch [120/200] finished in 469.07 seconds (7.82 minutes)
# Fold [4/4.0] | Epoch [120/200] | Train Loss: 0.5204 | Val Loss: 0.6881
# Current Epoch: 130 | Loss value 0.502059803425687
# Current Epoch: 130 | Validation Loss value 0.6764030115944999
# Epoch [130/200] finished in 464.39 seconds (7.74 minutes)
# Fold [4/4.0] | Epoch [130/200] | Train Loss: 0.5021 | Val Loss: 0.6764
# Early Break Activated
# Fold [4/4.0] | Epoch [136/200] | Train Loss: 0.4899 | Val Loss: 0.6988

# %% [markdown]
# ## Launch testing function:

# %%
# load trained network if needed
# create environment
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# load trained network
path = "trained_nets"
prefix = "svc_coarse"
model_name = "SVC_coarse_prototype_net_1"
optimizer_name = "AdamW"
tag = "best"
full_model_name = f"trained_nets/{prefix}_{model_name}_{optimizer_name}_{tag}.pt"
net = SVC_coarse_prototype_net_1()

print(full_model_name)
# Out:
# trained_nets/svc_coarse_SVC_coarse_prototype_net_1_AdamW_best.pt

# %%
test_table = test_rose_1_SVC_coarse (trained_net, output, threshold=0.5, use_amp=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 test_table = test_rose_1_SVC_coarse (trained_net, output, threshold=0.5, use_amp=True)
#
# NameError: name 'test_rose_1_SVC_coarse' is not defined
