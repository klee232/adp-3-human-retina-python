# %% [markdown]
# # training function (ROSE-1 DVC coarse) testing notebook:

# %% [markdown]
# This notebook is created for the intension of testing the training function for ROSE-1 SVC coarse model.

# %%
# add directory
import sys
sys.path.append(r"C:\Users\klee232\Desktop\Thesis\personal-GitHub\adp-3-human-retina-python\Phase_1_Segmentation")

# %%
# import all functions needed tested
# passed: successfully load all functions
from data_function_2D import * 
from models_2D import *

# %% [markdown]
# ## Load dataset:

# %% [markdown]
# ### Loading:

# %%
# run load_rose_1_dataset() function first 
output = load_rose_1_dataset()
# DVC
train_ROSE_DVC_org = output["train_ROSE_DVC_org"]
train_ROSE_DVC_orgGt = output["train_ROSE_DVC_orgGt"]
test_ROSE_DVC_org = output["test_ROSE_DVC_org"]
test_ROSE_DVC_orgGt = output["test_ROSE_DVC_orgGt"]

# %% [markdown]
# ## Launch training function:

# %%
trained_net = train_rose_1_DVC_coarse(output, num_epoch=200, learning_rate=3e-4, use_aug=True, early_break_counter=40)
# Out:
# C:\Users\klee232\Desktop\Thesis\personal-GitHub\adp-3-human-retina-python\Phase_1_Segmentation\models_2D\resume_checking.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(model_p, map_location=map_loc)
# C:\Users\klee232\Desktop\Thesis\personal-GitHub\adp-3-human-retina-python\Phase_1_Segmentation\models_2D\resume_checking.py:113: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt_param = torch.load(param_p, map_location=map_loc)
# 3
# 95

# %%
trained_net = train_rose_1_DVC_coarse(output, num_epoch=200, learning_rate=3e-4, use_aug=True, early_break_counter=40)
# Out:
# Current Epoch: 10 | Loss value 0.6834867327821021
# Current Epoch: 10 | Validation Loss value 0.6071071965353829
# Epoch [10/200] finished in 102.64 seconds (1.71 minutes)
# Fold [1/4.0] | Epoch [10/200] | Train Loss: 0.6835 | Val Loss: 0.6071
# Current Epoch: 20 | Loss value 0.6177496892564437
# Current Epoch: 20 | Validation Loss value 0.5500697408403669
# Epoch [20/200] finished in 97.57 seconds (1.63 minutes)
# Fold [1/4.0] | Epoch [20/200] | Train Loss: 0.6177 | Val Loss: 0.5501
# Current Epoch: 30 | Loss value 0.584158065249619
# Current Epoch: 30 | Validation Loss value 0.5175031253269741
# Epoch [30/200] finished in 94.96 seconds (1.58 minutes)
# Fold [1/4.0] | Epoch [30/200] | Train Loss: 0.5842 | Val Loss: 0.5175
# Current Epoch: 40 | Loss value 0.5642922720284138
# Current Epoch: 40 | Validation Loss value 0.5201517173222133
# Epoch [40/200] finished in 95.19 seconds (1.59 minutes)
# Fold [1/4.0] | Epoch [40/200] | Train Loss: 0.5643 | Val Loss: 0.5202
# Current Epoch: 50 | Loss value 0.5440930515817068
# Current Epoch: 50 | Validation Loss value 0.5127617291041783
# Epoch [50/200] finished in 95.99 seconds (1.60 minutes)
# Fold [1/4.0] | Epoch [50/200] | Train Loss: 0.5441 | Val Loss: 0.5128
# Current Epoch: 60 | Loss value 0.5274827101276917
# Current Epoch: 60 | Validation Loss value 0.5040604727608817
# Epoch [60/200] finished in 94.55 seconds (1.58 minutes)
# Fold [1/4.0] | Epoch [60/200] | Train Loss: 0.5275 | Val Loss: 0.5041
# Current Epoch: 70 | Loss value 0.5141616359497737
# Current Epoch: 70 | Validation Loss value 0.5087316717420306
# Epoch [70/200] finished in 95.27 seconds (1.59 minutes)
# Fold [1/4.0] | Epoch [70/200] | Train Loss: 0.5142 | Val Loss: 0.5087
# Current Epoch: 80 | Loss value 0.49249065243730356
# Current Epoch: 80 | Validation Loss value 0.508248141833714
# Epoch [80/200] finished in 95.51 seconds (1.59 minutes)
# Fold [1/4.0] | Epoch [80/200] | Train Loss: 0.4925 | Val Loss: 0.5082
# Current Epoch: 90 | Loss value 0.473146861328662
# Current Epoch: 90 | Validation Loss value 0.5111635412488665
# Epoch [90/200] finished in 97.87 seconds (1.63 minutes)
# Fold [1/4.0] | Epoch [90/200] | Train Loss: 0.4731 | Val Loss: 0.5112
# Current Epoch: 100 | Loss value 0.45174262824567774
# Current Epoch: 100 | Validation Loss value 0.5052532468523298
# Epoch [100/200] finished in 98.63 seconds (1.64 minutes)
# Fold [1/4.0] | Epoch [100/200] | Train Loss: 0.4517 | Val Loss: 0.5053
# Current Epoch: 110 | Loss value 0.42988822536141263
# Current Epoch: 110 | Validation Loss value 0.5182885272162301
# Epoch [110/200] finished in 98.57 seconds (1.64 minutes)
# Fold [1/4.0] | Epoch [110/200] | Train Loss: 0.4299 | Val Loss: 0.5183
# Early Break Activated
# Fold [1/4.0] | Epoch [119/200] | Train Loss: 0.4167 | Val Loss: 0.5261
# Current Epoch: 10 | Loss value 0.6404232857296768
# Current Epoch: 10 | Validation Loss value 0.6995296478271484
# Epoch [10/200] finished in 98.03 seconds (1.63 minutes)
# Fold [2/4.0] | Epoch [10/200] | Train Loss: 0.6404 | Val Loss: 0.6995
# Current Epoch: 20 | Loss value 0.6029480990854282
# Current Epoch: 20 | Validation Loss value 0.640765803200858
# Epoch [20/200] finished in 98.80 seconds (1.65 minutes)
# Fold [2/4.0] | Epoch [20/200] | Train Loss: 0.6029 | Val Loss: 0.6408
# Current Epoch: 30 | Loss value 0.6390496156748059
# Current Epoch: 30 | Validation Loss value 0.6681532689503261
# Epoch [30/200] finished in 99.61 seconds (1.66 minutes)
# Fold [2/4.0] | Epoch [30/200] | Train Loss: 0.6390 | Val Loss: 0.6682
# Current Epoch: 40 | Loss value 0.5754322340187518
# Current Epoch: 40 | Validation Loss value 0.6163655008588519
# Epoch [40/200] finished in 99.09 seconds (1.65 minutes)
# Fold [2/4.0] | Epoch [40/200] | Train Loss: 0.5754 | Val Loss: 0.6164
# Current Epoch: 50 | Loss value 0.5578696363180586
# Current Epoch: 50 | Validation Loss value 0.5992822306496757
# Epoch [50/200] finished in 99.65 seconds (1.66 minutes)
# Fold [2/4.0] | Epoch [50/200] | Train Loss: 0.5579 | Val Loss: 0.5993
# Current Epoch: 60 | Loss value 0.5459486309764454
# Current Epoch: 60 | Validation Loss value 0.5895716122218541
# Epoch [60/200] finished in 99.57 seconds (1.66 minutes)
# Fold [2/4.0] | Epoch [60/200] | Train Loss: 0.5459 | Val Loss: 0.5896
# Current Epoch: 70 | Loss value 0.532129366710348
# Current Epoch: 70 | Validation Loss value 0.5871340036392212
# Epoch [70/200] finished in 99.57 seconds (1.66 minutes)
# Fold [2/4.0] | Epoch [70/200] | Train Loss: 0.5321 | Val Loss: 0.5871
# Current Epoch: 80 | Loss value 0.5200896037435069
# Current Epoch: 80 | Validation Loss value 0.5725128991263253
# Epoch [80/200] finished in 99.61 seconds (1.66 minutes)
# Fold [2/4.0] | Epoch [80/200] | Train Loss: 0.5201 | Val Loss: 0.5725
# Current Epoch: 90 | Loss value 0.5095985086218825
# Current Epoch: 90 | Validation Loss value 0.5965109722954887
# Epoch [90/200] finished in 102.00 seconds (1.70 minutes)
# Fold [2/4.0] | Epoch [90/200] | Train Loss: 0.5096 | Val Loss: 0.5965
# Current Epoch: 100 | Loss value 0.5008274672679531
# Current Epoch: 100 | Validation Loss value 0.5792796100888934
# Epoch [100/200] finished in 102.84 seconds (1.71 minutes)
# Fold [2/4.0] | Epoch [100/200] | Train Loss: 0.5008 | Val Loss: 0.5793
# Current Epoch: 110 | Loss value 0.47760963208467055
# Current Epoch: 110 | Validation Loss value 0.5890895979745048
# Epoch [110/200] finished in 102.78 seconds (1.71 minutes)
# Fold [2/4.0] | Epoch [110/200] | Train Loss: 0.4776 | Val Loss: 0.5891
# Current Epoch: 120 | Loss value 0.4604464746215968
# Current Epoch: 120 | Validation Loss value 0.5995453425816127
# Epoch [120/200] finished in 104.82 seconds (1.75 minutes)
# Fold [2/4.0] | Epoch [120/200] | Train Loss: 0.4604 | Val Loss: 0.5995
# Current Epoch: 130 | Loss value 0.44140398213006915
# Current Epoch: 130 | Validation Loss value 0.6028880051204136
# Epoch [130/200] finished in 105.35 seconds (1.76 minutes)
# Fold [2/4.0] | Epoch [130/200] | Train Loss: 0.4414 | Val Loss: 0.6029
# Early Break Activated
# Fold [2/4.0] | Epoch [137/200] | Train Loss: 0.4303 | Val Loss: 0.6133
# Current Epoch: 10 | Loss value 0.6678751232554612
# Current Epoch: 10 | Validation Loss value 0.6800636393683297
# Epoch [10/200] finished in 108.52 seconds (1.81 minutes)
# Fold [3/4.0] | Epoch [10/200] | Train Loss: 0.6679 | Val Loss: 0.6801
# Current Epoch: 20 | Loss value 0.6186231542559504
# Current Epoch: 20 | Validation Loss value 0.6484848431178502
# Epoch [20/200] finished in 108.65 seconds (1.81 minutes)
# Fold [3/4.0] | Epoch [20/200] | Train Loss: 0.6186 | Val Loss: 0.6485
# Current Epoch: 30 | Loss value 0.5928361635763668
# Current Epoch: 30 | Validation Loss value 0.5797677380698067
# Epoch [30/200] finished in 108.00 seconds (1.80 minutes)
# Fold [3/4.0] | Epoch [30/200] | Train Loss: 0.5928 | Val Loss: 0.5798
# Current Epoch: 40 | Loss value 0.5671481299168856
# Current Epoch: 40 | Validation Loss value 0.558065584727696
# Epoch [40/200] finished in 107.43 seconds (1.79 minutes)
# Fold [3/4.0] | Epoch [40/200] | Train Loss: 0.5671 | Val Loss: 0.5581
# Current Epoch: 50 | Loss value 0.5584916755991075
# Current Epoch: 50 | Validation Loss value 0.5712616784232003
# Epoch [50/200] finished in 107.05 seconds (1.78 minutes)
# Fold [3/4.0] | Epoch [50/200] | Train Loss: 0.5585 | Val Loss: 0.5713
# Current Epoch: 60 | Loss value 0.5333757267414945
# Current Epoch: 60 | Validation Loss value 0.5502554178237915
# Epoch [60/200] finished in 106.69 seconds (1.78 minutes)
# Fold [3/4.0] | Epoch [60/200] | Train Loss: 0.5334 | Val Loss: 0.5503
# Current Epoch: 70 | Loss value 0.5230150095467428
# Current Epoch: 70 | Validation Loss value 0.5548755781991142
# Epoch [70/200] finished in 108.32 seconds (1.81 minutes)
# Fold [3/4.0] | Epoch [70/200] | Train Loss: 0.5230 | Val Loss: 0.5549
# Current Epoch: 80 | Loss value 0.5146498358944087
# Current Epoch: 80 | Validation Loss value 0.5534777130399432
# Epoch [80/200] finished in 106.56 seconds (1.78 minutes)
# Fold [3/4.0] | Epoch [80/200] | Train Loss: 0.5146 | Val Loss: 0.5535
# Current Epoch: 90 | Loss value 0.4953597839017516
# Current Epoch: 90 | Validation Loss value 0.5517153399331229
# Epoch [90/200] finished in 107.59 seconds (1.79 minutes)
# Fold [3/4.0] | Epoch [90/200] | Train Loss: 0.4954 | Val Loss: 0.5517
# Current Epoch: 100 | Loss value 0.4765211045742035
# Current Epoch: 100 | Validation Loss value 0.5618622984204974
# Epoch [100/200] finished in 107.46 seconds (1.79 minutes)
# Fold [3/4.0] | Epoch [100/200] | Train Loss: 0.4765 | Val Loss: 0.5619
# Current Epoch: 110 | Loss value 0.4650986116488003
# Current Epoch: 110 | Validation Loss value 0.5598998069763184
# Epoch [110/200] finished in 108.89 seconds (1.81 minutes)
# Fold [3/4.0] | Epoch [110/200] | Train Loss: 0.4651 | Val Loss: 0.5599
# Current Epoch: 120 | Loss value 0.44374433073025304
# Current Epoch: 120 | Validation Loss value 0.5686500753675189
# Epoch [120/200] finished in 106.93 seconds (1.78 minutes)
# Fold [3/4.0] | Epoch [120/200] | Train Loss: 0.4437 | Val Loss: 0.5687
# Early Break Activated
# Fold [3/4.0] | Epoch [124/200] | Train Loss: 0.4397 | Val Loss: 0.5715
# Current Epoch: 10 | Loss value 0.6600553514887986
# Current Epoch: 10 | Validation Loss value 0.5687453746795654
# Epoch [10/200] finished in 109.72 seconds (1.83 minutes)
# Fold [4/4.0] | Epoch [10/200] | Train Loss: 0.6601 | Val Loss: 0.5687
# Current Epoch: 20 | Loss value 0.621505413569656
# Current Epoch: 20 | Validation Loss value 0.5924296379089355
# Epoch [20/200] finished in 109.67 seconds (1.83 minutes)
# Fold [4/4.0] | Epoch [20/200] | Train Loss: 0.6215 | Val Loss: 0.5924
# Current Epoch: 30 | Loss value 0.6017549570324352
# Current Epoch: 30 | Validation Loss value 0.5793803078787667
# Epoch [30/200] finished in 109.88 seconds (1.83 minutes)
# Fold [4/4.0] | Epoch [30/200] | Train Loss: 0.6018 | Val Loss: 0.5794
# Current Epoch: 40 | Loss value 0.5750378222720137
# Current Epoch: 40 | Validation Loss value 0.5515074729919434
# Epoch [40/200] finished in 108.25 seconds (1.80 minutes)
# Fold [4/4.0] | Epoch [40/200] | Train Loss: 0.5750 | Val Loss: 0.5515
# Current Epoch: 50 | Loss value 0.5537800013440327
# Current Epoch: 50 | Validation Loss value 0.5597893169948033
# Epoch [50/200] finished in 109.61 seconds (1.83 minutes)
# Fold [4/4.0] | Epoch [50/200] | Train Loss: 0.5538 | Val Loss: 0.5598
# Current Epoch: 60 | Loss value 0.5333694647816778
# Current Epoch: 60 | Validation Loss value 0.5340051991598946
# Epoch [60/200] finished in 109.18 seconds (1.82 minutes)
# Fold [4/4.0] | Epoch [60/200] | Train Loss: 0.5334 | Val Loss: 0.5340
# Current Epoch: 70 | Loss value 0.5169397954223225
# Current Epoch: 70 | Validation Loss value 0.5330068724496024
# Epoch [70/200] finished in 109.10 seconds (1.82 minutes)
# Fold [4/4.0] | Epoch [70/200] | Train Loss: 0.5169 | Val Loss: 0.5330
# Current Epoch: 80 | Loss value 0.5064791759240974
# Current Epoch: 80 | Validation Loss value 0.5330649273736137
# Epoch [80/200] finished in 109.05 seconds (1.82 minutes)
# Fold [4/4.0] | Epoch [80/200] | Train Loss: 0.5065 | Val Loss: 0.5331
# Current Epoch: 90 | Loss value 0.49069853749090026
# Current Epoch: 90 | Validation Loss value 0.5454866545540946
# Epoch [90/200] finished in 109.07 seconds (1.82 minutes)
# Fold [4/4.0] | Epoch [90/200] | Train Loss: 0.4907 | Val Loss: 0.5455
# Early Break Activated
# Fold [4/4.0] | Epoch [94/200] | Train Loss: 0.4854 | Val Loss: 0.5264
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 trained_net = train_rose_1_DVC_coarse(output, num_epoch=200, learning_rate=3e-4, use_aug=True, early_break_counter=40)
#
# File ~\Desktop\Thesis\personal-GitHub\adp-3-human-retina-python\Phase_1_Segmentation\models_2D\training_rose_1_DVC_coarse.py:342, in train_rose_1_DVC_coarse(overall_data, num_epoch, learning_rate, checkpoint_dir, prefix, use_amp, use_aug, early_break_counter)
#     340 handles, labels = ax.get_legend_handles_labels()
#     341 uniquie = dict(zip(labels, handles))
# --> 342 ax.legent(unique.values(), unique.keys(), ncol=2)
#     343 plt.xlabel('Epoch')
#     344 plt.ylabel('Loss')
#
# AttributeError: 'Axes' object has no attribute 'legent'

# %% [markdown]
# ## Launch testing function:

# %%
# load trained network if needed
# create environment
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# load trained network
path = "trained_nets"
prefix = "dvc_coarse"
model_name = "DVC_coarse_prototype_net_1"
optimizer_name = "AdamW"
tag = "best"
full_model_name = f"trained_nets/{prefix}_{model_name}_{optimizer_name}_{tag}.pt"
trained_net = DVC_coarse_prototype_net_1()
trained_net = trained_net.to(device)
checkpoint = torch.load(full_model_name, map_location=device)
trained_net.load_state_dict(checkpoint["model_state"])
# Out:
# C:\Users\klee232\AppData\Local\Temp\ipykernel_50144\1564124718.py:14: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(full_model_name, map_location=device)
# <All keys matched successfully>

# %%
test_table = test_rose_1_DVC_coarse (trained_net, output, threshold=0.5, use_amp=True)
